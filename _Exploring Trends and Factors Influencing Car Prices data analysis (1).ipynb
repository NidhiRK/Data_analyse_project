# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px # for data visualization i.e provides function to analys and visualize data

# %%
data_frame = pd.read_csv("car_prices.csv")
data_frame # data_frame --> It will show all the col and row in df(data_frame)
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer   color  \
# 0         automatic  5xyktca69fg566472    ca        5.0   16639.0   white
# ...

# %%
data_frame.head() # head()--> used to display the only 1st 5 row from the data_frame(by default)
# Out:
#    year   make                model        trim   body transmission  \
# 0  2015    Kia              Sorento          LX    SUV    automatic
# 1  2015    Kia              Sorento          LX    SUV    automatic
# 2  2014    BMW             3 Series  328i SULEV  Sedan    automatic
# 3  2015  Volvo                  S60          T5  Sedan    automatic
# 4  2014    BMW  6 Series Gran Coupe        650i  Sedan    automatic
#
#                  vin state  condition  odometer  color interior  \
# 0  5xyktca69fg566472    ca        5.0   16639.0  white    black
# 1  5xyktca69fg561319    ca        5.0    9393.0  white    beige
# 2  wba3c1c51ek116351    ca       45.0    1331.0   gray    black
# 3  yv1612tb4f1310987    ca       41.0   14282.0  white    black
# 4  wba6b2c57ed129731    ca       43.0    2641.0   gray    black
#
#                                    seller      mmr  sellingprice  \
# 0                 kia motors america  inc  20500.0       21500.0
# ...

# %%
data_frame.head(10)
# Out:
#    year       make                model                       trim  \
# 0  2015        Kia              Sorento                         LX
# 1  2015        Kia              Sorento                         LX
# 2  2014        BMW             3 Series                 328i SULEV
# 3  2015      Volvo                  S60                         T5
# 4  2014        BMW  6 Series Gran Coupe                       650i
# 5  2015     Nissan               Altima                      2.5 S
# 6  2014        BMW                   M5                       Base
# 7  2014  Chevrolet                Cruze                        1LT
# 8  2014       Audi                   A4  2.0T Premium Plus quattro
# 9  2014  Chevrolet               Camaro                         LT
#
#           body transmission                vin state  condition  odometer  \
# 0          SUV    automatic  5xyktca69fg566472    ca        5.0   16639.0
# 1          SUV    automatic  5xyktca69fg561319    ca        5.0    9393.0
# ...

# %%
data_frame.tail()  # tail()-->  used to display the only Last 5 row from the data_frame(by default)
# Out:
#         year    make   model         trim       body transmission  \
# 558832  2015     Kia    K900       Luxury      Sedan          NaN
# 558833  2012     Ram    2500  Power Wagon   Crew Cab    automatic
# 558834  2012     BMW      X5    xDrive35d        SUV    automatic
# 558835  2015  Nissan  Altima        2.5 S      sedan    automatic
# 558836  2014    Ford   F-150          XLT  SuperCrew    automatic
#
#                       vin state  condition  odometer   color interior  \
# 558832  knalw4d4xf6019304    in       45.0   18255.0  silver    black
# 558833  3c6td5et6cg112407    wa        5.0   54393.0   white    black
# 558834  5uxzw0c58cl668465    ca       48.0   50561.0   black    black
# 558835  1n4al3ap0fc216050    ga       38.0   16658.0   white    black
# 558836  1ftfw1et2eke87277    ca       34.0   15008.0    gray     gray
#
#                                                    seller      mmr  \
# 558832                                   avis corporation  35300.0
# ...

# %%
data_frame.shape # shape --> showa to total number of row and columns from the dataset
# Out:
# (558837, 16)

# %%
data_frame.columns # columns --> use to show all columns name from data set
# Out:
# Index(['year', 'make', 'model', 'trim', 'body', 'transmission', 'vin', 'state',
#        'condition', 'odometer', 'color', 'interior', 'seller', 'mmr',
#        'sellingprice', 'saledate'],
#       dtype='object')

# %%
data_frame.info # info --> it will show information about the data set
# Out:
# <bound method DataFrame.info of         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer   color  \
# ...

# %%
data_frame.info() #info() --> it will show information about the data set like (data types)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558837 entries, 0 to 558836
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   year          558837 non-null  int64
#  1   make          548536 non-null  object
#  2   model         548438 non-null  object
#  3   trim          548186 non-null  object
#  4   body          545642 non-null  object
#  5   transmission  493485 non-null  object
#  6   vin           558833 non-null  object
#  7   state         558837 non-null  object
#  8   condition     547017 non-null  float64
#  9   odometer      558743 non-null  float64
#  10  color         558088 non-null  object
#  11  interior      558088 non-null  object
#  12  seller        558837 non-null  object
#  13  mmr           558799 non-null  float64
#  14  sellingprice  558825 non-null  float64
#  15  saledate      558825 non-null  object
# dtypes: float64(4), int64(1), object(11)
# memory usage: 68.2+ MB

# %%
# Handling missing values
data_frame.dropna(inplace=True)  # Drop rows with missing values
# Or fill missing values with appropriate methods like mean, median, or mode

# Removing duplicates
data_frame.drop_duplicates(inplace=True)

# Handling inconsistent data
# This might involve standardizing text data, correcting erroneous values, etc.

# %%
data_frame.isnull().sum()
# Out:
# year            0
# make            0
# model           0
# trim            0
# body            0
# transmission    0
# vin             0
# state           0
# condition       0
# odometer        0
# color           0
# interior        0
# seller          0
# mmr             0
# sellingprice    0
# saledate        0
# dtype: int64

# %%
data_frame.nunique() # nunique() --> It's use to show the noumer of total unique value of the col from data set
# Out:
# year                34
# make                96
# model              973
# trim              1963
# body                87
# transmission         4
# vin             550297
# state               64
# condition           41
# odometer        172278
# color               46
# interior            17
# seller           14263
# mmr               1101
# sellingprice      1887
# saledate          3766
# dtype: int64

# %%
data_frame["state"].unique
# Out:
# <bound method Series.unique of 0         ca
# 1         ca
# 2         ca
# 3         ca
# 4         ca
#           ..
# 558832    in
# 558833    wa
# 558834    ca
# 558835    ga
# 558836    ca
# Name: state, Length: 558837, dtype: object>

# %%
data_frame["model"].unique
# Out:
# <bound method Series.unique of 0                     Sorento
# 1                     Sorento
# 2                    3 Series
# 3                         S60
# 4         6 Series Gran Coupe
#                  ...
# 558831               5 Series
# 558833                   2500
# 558834                     X5
# 558835                 Altima
# 558836                  F-150
# Name: model, Length: 472325, dtype: object>

# %%
data_frame.count() # count() --> use to count the all value of the col
# Out:
# year            558837
# make            548536
# model           548438
# trim            548186
# body            545642
# transmission    493485
# vin             558833
# state           558837
# condition       547017
# odometer        558743
# color           558088
# interior        558088
# seller          558837
# mmr             558799
# sellingprice    558825
# saledate        558825
# dtype: int64

# %%
data_frame.describe()
# Out:
#                 year      condition       odometer            mmr  \
# count  558837.000000  547017.000000  558743.000000  558799.000000
# mean     2010.038927      30.672365   68320.017767   13769.377495
# std         3.966864      13.402832   53398.542821    9679.967174
# min      1982.000000       1.000000       1.000000      25.000000
# 25%      2007.000000      23.000000   28371.000000    7100.000000
# 50%      2012.000000      35.000000   52254.000000   12250.000000
# 75%      2013.000000      42.000000   99109.000000   18300.000000
# max      2015.000000      49.000000  999999.000000  182000.000000
#
#         sellingprice
# count  558825.000000
# mean    13611.358810
# std      9749.501628
# min         1.000000
# 25%      6900.000000
# 50%     12100.000000
# 75%     18200.000000
# max    230000.000000

# %%
 # Price Distribution
plt.hist(data_frame['sellingprice'], bins=20)
plt.title('Price Distribution')
plt.xlabel('Selling Price')
plt.ylabel('Frequency')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming data_frame is your DataFrame
# Let's say you want to visualize the distribution of car makes

# Grouping by 'make' column and counting the occurrences of each make
make_counts = data_frame['make'].value_counts()

# Plotting a bar chart
plt.figure(figsize=(10, 6))
make_counts.plot(kind='bar')
plt.title('Distribution of Car Makes')
plt.xlabel('Car Make')
plt.ylabel('Count')
plt.xticks(rotation=45)  # Rotating x-axis labels for better readability
plt.grid(axis='y')  # Adding gridlines along the y-axis
plt.show()

# %%
plt.scatter(data_frame.state,data_frame.year)
plt.show()

# %%
data_frame.groupby('state')['seller'].sum().sort_values(ascending = True).head(10)
# Out:
# state
# tx                   ars/express car and truck rental inccapps rent...
# nm                   automotive remarketing incwestlake financial s...
# in                   avis corporationchrysler capitalavis corporati...
# mo                   avis corporationthe hertz corporationge fleet ...
# nc                   avis rac/damage/charlottec&f finance companysa...
# nv                   avis rac/los angelesauto & truck directprestig...
# 3vwd17aj9fm219766                                                black
# 3vwd17aj8fm298895                                                black
# 3vwd17aj8fm239622                                                black
# 3vwd17aj7fm326640                                                black
# Name: seller, dtype: object

# %%
data_frame.mmr<30000
# Out:
# 0          True
# 1          True
# 2         False
# 3          True
# 4         False
#           ...
# 558832    False
# 558833    False
# 558834     True
# 558835     True
# 558836     True
# Name: mmr, Length: 558837, dtype: bool

# %%
# Price by Make
sns.boxplot(x='make', y='sellingprice', data=data_frame)
plt.title('Price by Make')
plt.xlabel('Make')
plt.ylabel('Selling Price')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\TURBOC3\python39\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\TURBOC3\python39\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\TURBOC3\python39\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
# Price vs. Odometer
plt.scatter(data_frame['odometer'], data_frame['sellingprice'])
plt.title('Price vs. Odometer')
plt.xlabel('Odometer')
plt.ylabel('Selling Price')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(data_frame['sellingprice'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Car Prices')
plt.xlabel('Selling Price')
plt.ylabel('Frequency')
plt.show()

# %%
body_counts = data_frame['body'].value_counts()

plt.figure(figsize=(8, 8))
plt.pie(body_counts, labels=body_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Car Body Types')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='condition', y='sellingprice', data=data_frame, palette='Set2')
plt.title('Selling Price by Car Condition')
plt.xlabel('Condition')
plt.ylabel('Selling Price')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\TURBOC3\python39\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\TURBOC3\python39\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\TURBOC3\python39\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
plt.figure(figsize=(10, 6))
plt.scatter(data_frame['odometer'], data_frame['sellingprice'], color='green')
plt.title('Selling Price vs. Mileage')
plt.xlabel('Mileage')
plt.ylabel('Selling Price')
plt.show()
